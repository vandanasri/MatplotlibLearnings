# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib widget
fig = plt.figure()
ax = plt.axes(projection = '3d')
x = [1,2,3,4,5]
y =[5,6,7,8,9]
X,Y = np.meshgrid(x,y)
Z = np.sin(np.sqrt(X**2 + Y**2))
print(Z)
# plot wireframe
ax.plot_wireframe(X,Y,Z, color = 'b')
ax.set_xlabel('X-Axis')
ax.set_ylabel('Y-Axis')
ax.set_zlabel('Z-Axis')
ax.set_title('3-D Wireframe')
# Out:
# [[-0.92618484 -0.7820949  -0.43697552  0.11965158  0.70886129]
#  [-0.19908366  0.04135821  0.41233775  0.80037306  0.99904391]
#  [ 0.70886129  0.83980535  0.97176225  0.97838882  0.73281691]
#  [ 0.97838882  0.92405909  0.77123194  0.46222798 -0.00920304]
#  [ 0.36104928  0.20379577 -0.0620152  -0.41148231 -0.76487817]]
# Text(0.5, 0.92, '3-D Wireframe')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
